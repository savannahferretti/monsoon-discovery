# %%
import os
import json
import warnings
import numpy as np
import pandas as pd
import xarray as xr
import proplot as pplt
warnings.filterwarnings('ignore')
pplt.rc.update({
    'savefig.dpi':900,
    'savefig.bbox':'tight',
    'savefig.pad_inches':0.02,
    'tick.minor':False,
    'font.size':9,
    'label.size':9,
    'tick.labelsize':9,
    'title.size':9,
    'abc.size':9,
    'legend.fontsize':9,
    'suptitle.size':9,
    'leftlabelsize':9,
    'toplabelsize':9,
    'leftlabel.weight':'normal',
    'toplabel.weight':'normal',
    'reso':'xx-hi'})

# %%
with open('../scripts/configs.json','r',encoding='utf-8') as f:
    CONFIGS = json.load(f)
SPLITSDIR  = CONFIGS['filepaths']['splits']
WEIGHTSDIR = CONFIGS['filepaths']['weights']
MODELS     = CONFIGS['experiments']
VARLABELS  = {
    'rh':'RH',
    'thetae':r'$\mathit{\theta_{e}}$',
    'thetaestar':r'$\mathit{\theta_{e}}^*$'}

# %%
with xr.open_dataset(f'{SPLITSDIR}/train.h5',engine='h5netcdf') as ds:
    sig = ds['sig'].load()

results = []
for name in MODELS['nn']['runs']:
    if 'nonparam' in name or 'gauss' in name:
        klist = []
        for seed in MODELS['nn']['seeds']:
            filepath = os.path.join(WEIGHTSDIR,f'{name}_{seed}_weights.nc')
            with xr.open_dataset(filepath,engine='h5netcdf') as ds:
                klist.append(ds.k.load())
        k = xr.concat(klist,dim='seed')
        kmean = k.mean('seed')
        kstd  = k.std('seed')
        results.append((name,kmean,kstd))

print(f'Found {len(results)} kernel models with saved weights!')
# Out:
# Found 2 kernel models with saved weights!

# %%
rowlabels = ['Nonparametric Kernel','Gaussian Kernel']
collabels = [v for v in VARLABELS.values()]
fig,axs = pplt.subplots(nrows=len(results),ncols=len(VARLABELS),figwidth=4,refheight=1.4,share=True,space=0)
axs.format(grid=False,rowlabels=rowlabels,collabels=collabels,xlabel='Kernel Weight',
           ylabel='$\\sigma$',ylim=(1,0.5),yticks=[0.95,0.85,0.75,0.65,0.55])
for row,(name,*data) in enumerate(results):
    for col in range(len(collabels)):
        ax = axs[row,col]
        if row!=len(rowlabels)-1:
            ax.tick_params(axis='x',bottom=False,labelbottom=False)
        if col!=0:
            ax.tick_params(axis='y',left=False,labelleft=False)
        ax.axvline(0,color='gray',linewidth=0.5)
        mean,std = data[0].isel(field=col),data[1].isel(field=col)
        ax.plot(mean,sig,color='#D42028',linewidth=1,label='Mean')
        ax.fill_betweenx(sig,mean-std,mean+std,color='#D42028',alpha=0.2,label=r'$\pm 1\sigma$')
        ax.format(xlim=(-5.5,5.5),xticks=3)
axs[1,0].legend(loc='ul',ncols=1,frame=False)
pplt.show()
fig.save('../figs/fig_S1.jpg')
# Out:
# Figure(nrows=2, ncols=3, refheight=1.4, figwidth=4.0)

# %%
gauss     = next(r for r in results if 'gauss' in r[0])
gaussmean = gauss[1]
gaussstd  = gauss[2]
an21  = 0.9
wb06  = 0.7

fig,axs = pplt.subplots(ncols=len(VARLABELS),figwidth=5,refheight=2.4,share=True,space=0)
axs.format(grid=False,collabels=list(VARLABELS.values()),xlabel='Kernel Weight',
           ylabel=r'$\sigma$',ylim=(1,0.5),yticks=[0.95,0.85,0.75,0.65,0.55])
for col,varkey in enumerate(VARLABELS):
    ax = axs[col]
    if col!=0:
        ax.tick_params(axis='y',left=False,labelleft=False)
    ax.axvline(0,color='gray',linewidth=0.5)
    ax.axhline(wb06,color='yellow6',lw=1,ls=':',zorder=0)
    ax.axhline(an21,color='blue6',lw=1,ls='--',zorder=0)
    mean = gaussmean.isel(field=col)
    std  = gaussstd.isel(field=col)
    ax.plot(mean,sig,color='#D42028',lw=1,zorder=1)
    ax.fill_betweenx(sig,mean-std,mean+std,color='#D42028',alpha=0.2,zorder=1)
    ax.format(xlim=(-5.5,5.5),xticks=3)

axs[0].text(-5.3,an21-0.03,'Ahmed et al. (2021)',va='top',ha='left',fontsize=7)
axs[0].text(-5.3,wb06-0.03,'Wood et al. (2004)',va='top',ha='left',fontsize=7)

pplt.show()
fig.save('../figs/fig_2.jpg')
# Out:
# Figure(nrows=1, ncols=3, refheight=2.4, figwidth=5.0)

# %%
sigarr  = sig.values
dsigarr = np.abs(np.gradient(sigarr))
labels  = VARLABELS.values()

rows = []
for name,kmean,_ in results:
    if 'nonparam' in name:
        continue
    for i,varname in enumerate(labels):
        k      = kmean.isel(field=i).values
        pi     = np.argmax(k)
        center = float(sigarr[pi])
        width  = float(np.sqrt(((sigarr-center)**2*k*dsigarr).sum()))
        rows.append({'Predictor':varname,r'$\sigma_c$':round(center,2),r'$\sigma_w$':round(width,3)})

df = pd.DataFrame(rows)
display(df.style.hide(axis='index').format(precision=3))
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac120">
#   <thead>
#     <tr>
#       <th id="T_ac120_level0_col0" class="col_heading level0 col0" >Predictor</th>
#       <th id="T_ac120_level0_col1" class="col_heading level0 col1" >$\sigma_c$</th>
#       <th id="T_ac120_level0_col2" class="col_heading level0 col2" >$\sigma_w$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ac120_row0_col0" class="data row0 col0" >RH</td>
#       <td id="T_ac120_row0_col1" class="data row0 col1" >0.500</td>
#       <td id="T_ac120_row0_col2" class="data row0 col2" >0.237</td>
#     </tr>
#     <tr>
#       <td id="T_ac120_row1_col0" class="data row1 col0" >$\mathit{\theta_{e}}$</td>
#       <td id="T_ac120_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_ac120_row1_col2" class="data row1 col2" >0.130</td>
#     </tr>
#     <tr>
#       <td id="T_ac120_row2_col0" class="data row2 col0" >$\mathit{\theta_{e}}^*$</td>
#       <td id="T_ac120_row2_col1" class="data row2 col1" >0.750</td>
#       <td id="T_ac120_row2_col2" class="data row2 col2" >0.117</td>
#     </tr>
#   </tbody>
# </table>
